# %% [markdown]
# An introduction to Conda
# =============
#
# Conda is at its heart a command line tool which allows you to manage _packages_ inside of _environments_. It ensures that when a new package is added, it is compatible with the existing _environment_, and transparently handles upgrading environments while keeping these compatiblity constraints in mind. It originated out of the needs of the scientific Python community, but has broadened to be useful for many languages and environments, including R. The data science company Anaconda created `conda`, and it is open source. Esri uses `conda` to distribute our packages, and it is included with ArcGIS Pro and ArcGIS Server, among other products.
#
# This notebook shows you the ropes of using conda via the Jupyter notebook, but the commands run here would typically be run instead from the command line. If you have ArcGIS Pro installed, you can start the active conda environment that is being used by Pro by running the `Python Command Prompt` shortcut.

# %% [markdown]
# Listing packages
# ------------------
#
# To start with, you might want to know what an environment contains. This environment, `arcgispro-r`, contains the full set of Python packages used by ArcGIS (such as ArcPy, but also over 80 others), and a full R installation, including this Jupyter Notebook environment. You can list the available packages with the `conda list` command.
#
# _Note_:  we start this command with an exclaimation point, `!` which tells Jupyter to run the command as a shell command instead of a Python or R command.

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\shau7031\AppData\Local\ESRI\conda\envs\arcgispro-r:
# #
# _r-mutex                  1.0.0                     mro_2
# arcgis                    1.4.1            py36h52c3b5e_1    esri
# arcgispro                 2.2                           0    esri
# asn1crypto                0.24.0                   py36_0
# attrs                     17.4.0                   py36_0
# backcall                  0.1.0                    py36_0
# bleach                    2.1.3                    py36_0
# ca-certificates           2018.03.07                    0
# certifi                   2018.1.18                py36_0
# cffi                      1.11.5           py36h945400d_0
# chardet                   3.0.4            py36h420ce6e_1
# colorama                  0.3.9            py36h029ae33_0
# cryptography              2.2.2            py36hfa6e2cd_0
# cycler                    0.10.0           py36h009560c_0
# decorator                 4.2.1                    py36_0
# entrypoints               0.2.3            py36hfd66bb0_2
# et_xmlfile                1.0.1            py36h3d2d736_0
# freetype                  2.8                      vc14_0  [vc14]  esri
# future                    0.16.0                   py36_1    esri
# html5lib                  1.0.1            py36h047fa9f_0
# icc_rt                    2018.0.2            arcgispro_0  [arcgispro]  esri
# idna                      2.6              py36h148d497_1
# intel-openmp              2018.0.0            arcgispro_0  [arcgispro]  esri
# ipykernel                 4.8.2                    py36_0
# ipython                   6.3.1                    py36_0
# ipython_genutils          0.2.0            py36h3c5d0ee_0
# ipywidgets                7.2.1                    py36_0
# jdcal                     1.4                      py36_0
# jedi                      0.11.1                   py36_0    esri
# jinja2                    2.10             py36h292fed1_0
# jsonschema                2.6.0            py36h7636477_0
# jupyter_client            5.2.3                    py36_0
# jupyter_console           5.2.0            py36h6d89b47_1
# jupyter_core              4.4.0            py36h56e9d50_0
# keyring                   11.0.0                   py36_0    esri
# kiwisolver                1.0.1            py36h12c3424_0
# libpng                    1.6.34               h79bbb47_0
# markupsafe                1.0              py36h0e26971_1
# matplotlib                2.2.2                   py36_0e  [arcgispro]  esri
# mistune                   0.8.3                    py36_0
# mkl                       2018.0.2            arcgispro_2  [arcgispro]  esri
# mkl_fft                   1.0.1            py36h452e1ab_0
# mkl_random                1.0.1            py36h9258bd6_0
# more-itertools            4.1.0                    py36_0
# mpmath                    1.0.0            py36hacc8adf_2
# mro-base                  3.4.3                         0
# mro-basics                3.4.3                         0
# nbconvert                 5.3.1                    py36_1    esri
# nbformat                  4.4.0            py36h3a5bc1b_0
# netcdf4                   1.3.1                    py36_1  [arcgispro]  esri
# nose                      1.3.7            py36h1c3779e_2
# notebook                  5.4.1                    py36_0
# numexpr                   2.6.4            py36h30784b8_0
# numpy                     1.14.2           py36h5c71026_1
# openpyxl                  2.5.2                    py36_0
# openssl                   1.0.2o               h8ea7d77_0
# pandas                    0.22.0           py36h6538335_0
# pandocfilters             1.4.2            py36h3ef6317_1
# parso                     0.1.1            py36hae3edee_0
# pickleshare               0.7.4            py36h9de030f_0
# pip                       9.0.3                    py36_0
# pluggy                    0.6.0            py36hc7daf1e_0
# prompt_toolkit            1.0.15           py36h60b8f86_0
# py                        1.5.3                    py36_0
# pycparser                 2.18             py36hd053e01_1
# pygments                  2.2.0            py36hb010967_0
# pyopenssl                 17.5.0           py36h5b7d817_0
# pyparsing                 2.2.0            py36h785a196_1
# pypdf2                    1.26.0                     py_2    esri
# pyshp                     1.2.12           py36h9b5cf0b_0
# pysocks                   1.6.8                    py36_0
# pytest                    3.5.0                    py36_0
# python                    3.6.5                h0c2934d_0
# python-dateutil           2.7.2                    py36_0
# pytz                      2018.3                   py36_0    esri
# pywin32-ctypes            0.1.2                    py36_0    esri
# pywinpty                  0.5                      py36_0    esri
# pyzmq                     17.0.0           py36hfa6e2cd_0
# r-assertthat              0.2.0           mro343h889e2dd_0
# r-backports               1.1.2           mro343h889e2dd_0
# r-base64enc               0.1_3           mro343h889e2dd_0
# r-bh                      1.65.0_1        mro343h889e2dd_0
# r-bindr                   0.1             mro343h889e2dd_0
# r-bindrcpp                0.2             mro343h889e2dd_0
# r-boot                    1.3_20                 mro343_0
# r-broom                   0.4.3           mro343h889e2dd_0
# r-callr                   1.0.0           mro343h889e2dd_0
# r-caret                   6.0_78          mro343h889e2dd_0
# r-cellranger              1.1.0           mro343h889e2dd_0
# r-checkpoint              0.4.3                  mro343_0
# r-class                   7.3_14                 mro343_0
# r-cli                     1.0.0           mro343h889e2dd_0
# r-clipr                   0.4.0           mro343h889e2dd_0
# r-cluster                 2.0.6                  mro343_0
# r-codetools               0.2_15                 mro343_0
# r-colorspace              1.3_2           mro343h889e2dd_0
# r-crayon                  1.3.4           mro343h889e2dd_0
# r-curl                    3.1                    mro343_0
# r-cvst                    0.2_1           mro343h889e2dd_0
# r-data.table              1.10.4_3        mro343h889e2dd_0
# r-dbi                     0.7             mro343h889e2dd_0
# r-dbplyr                  1.1.0           mro343h889e2dd_0
# r-ddalpha                 1.3.1           mro343h889e2dd_0
# r-deoptimr                1.0_8           mro343h889e2dd_0
# r-deployrrserve           9.0.0                  mro343_0
# r-dichromat               2.0_0           mro343h889e2dd_0
# r-digest                  0.6.13          mro343h889e2dd_0
# r-dimred                  0.1.0           mro343h889e2dd_0
# r-doparallel              1.0.12                 mro343_0
# r-dplyr                   0.7.4           mro343h889e2dd_0
# wheel                     0.31.0                   py36_0
# widgetsnbextension        3.2.1                    py36_0
# win_inet_pton             1.0.1            py36he67d7fd_1
# wincertstore              0.2              py36h7fe50ca_0
# winkerberos               0.7.0                    py36_0
# winpty                    0.4.3                         4
# xlrd                      1.1.0            py36h1cb58dc_1
# xlwt                      1.3.0            py36h1a4751e_0
# zlib                      1.2.11               h8395fce_2

# %% [markdown]
# OK, so a ton of packages. We could also look at this environment from ArcGIS Pro, which provides the same information, but in a graphical interface:
#
# ![ArcGIS Pro R environment](image/pro-r-environment.png)

# %% [markdown]
# Listing Environments
# -----------------------
#
# We often need to switch between environments, and see what environemnts we have around. For that, we can use `conda env list`, or the shorter `conda info -e` to find what environments are available

# %%
# !conda info -e
# Out:
# # conda environments:
# #
# arcgispro-py3-tensorflow     C:\Users\shau7031\AppData\Local\ESRI\conda\envs\arcgispro-py3-tensorflow
# arcgispro-r           *  C:\Users\shau7031\AppData\Local\ESRI\conda\envs\arcgispro-r
# geomorphometry-tools     C:\Users\shau7031\AppData\Local\ESRI\conda\envs\geomorphometry-tools
# scipy                    C:\Users\shau7031\AppData\Local\ESRI\conda\envs\scipy
# test                     C:\Users\shau7031\AppData\Local\ESRI\conda\envs\test
# arcgispro-py3            C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3
# root                     C:\Program Files\ArcGIS\Pro\bin\Python

# %% [markdown]
# We won't run `activate <environment name>` now, because we want to keep running the current environment for this notebook, but if we wanted to, we could run
#
#     activate arcgispro-py3
#
# And that would change us to the default environment ArcGIS Pro ships with instead of our R augmented environment.

# %% [markdown]
# Installing packages
# ----------------------
#
# We can easily search for and install packages with Conda. Again, using Pro we can use the UI, but soemtimes its helpful to know the underlying command line tools, for scripting uses or more complex cases that the UI doesn't cove. Here, let's search for a package `xgboost`, a machine learning library that has bindings for multiple languages:

# %%
# !conda search xgboost
# Out:
# Fetching package metadata ...............
# _py-xgboost-mutex            2.0                       cpu_0  defaults
# _r-xgboost-mutex             2.0                       cpu_0  defaults
# libxgboost                   0.60                 h1133f5d_0  defaults
#                              0.7                  h6538335_0  defaults
#                              0.71                 h6538335_0  defaults
#                              0.72                          0  defaults
# py-xgboost                   0.60            py27np112haef2c84_0  defaults
#                              0.60            py35np112h24854b6_0  defaults
#                              0.60            py36np112h982e225_0  defaults
#                              0.7              py27h6538335_0  defaults
#                              0.7              py35h6538335_0  defaults
#                              0.7              py36h6538335_0  defaults
#                              0.71             py35h6538335_0  defaults
#                              0.71             py27hc56fc5f_0  defaults
#                              0.71             py36h6538335_0  defaults
#                              0.72             py35h6538335_0  defaults
#                              0.72             py36h6538335_0  defaults
#                              0.72             py27hc56fc5f_0  defaults
# py-xgboost-cpu               0.72                     py35_0  defaults
#                              0.72                     py36_0  defaults
#                              0.72                     py27_0  defaults
# r-xgboost                    0.7              r343h22c98a9_0  defaults
#                              0.7             mro343hb8b1496_0  defaults
#                              0.60             r332hac3f3dd_0  defaults
#                              0.71            mro343hb8b1496_0  defaults
#                              0.71             r343h22c98a9_0  defaults
#                              0.72            mro343h9e8cafe_0  defaults
#                              0.72             r343hc004794_0  defaults
# r-xgboost-cpu                0.72            mro343h9e8cafe_0  defaults
#                              0.72             r343hc004794_0  defaults

# %% [markdown]
# OK, we see a number of different versions available, for multiple langauges (the `py-` ones are for Python, and the `r-` ones are for R. Let's install `r-xgboost`, and the columns are name, version, package hash, and channel):

# %%
# !conda install --name arcgispro-r --yes r-xgboost
# Out:
# Fetching package metadata ...............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at C:\Users\shau7031\AppData\Local\ESRI\conda\envs\arcgispro-r:
# #
# r-xgboost                 0.72            mro343h9e8cafe_0

# %% [markdown]
# Upgrading packages
# ---------------------
#
# Can upgrade individual packages with `conda upgrade <package>`, such as `conda upgrade r-dplyr`. Or, you can upgrade all packages with `conda upgrade --all`.
#
# Using channels
# ----------------
#
# By default, conda searches the `defaults` channel for packages. Channels, which contain separate collections of packages, are hosted online at [anaconda.org](https://anaconda.org). Some additional important ones:
#
# Channel | Role
# --------|------
# conda-forge | A broad collection of community curated versions of packages, often more up-to-date than the defaults channel.
# esri | Packages Esri creates and maintains. Many packages distributed with ArcGIS Pro, but also contains extensions and utilities.
# r | A channel hosting updated R and Microsoft R Open packages
#
# To use a channel, pass the `--channel <name>` or `-c <name>` flag. Here, let's install a collection of test suites from the Esri channel:

# %%
# !conda install --channel esri --yes arcgispro-py36-extras
# Out:
# Fetching package metadata ...............
# Solving package specifications: .
#
# Package plan for installation in environment C:\Users\shau7031\AppData\Local\ESRI\conda\envs\arcgispro-r:
#
# The following NEW packages will be INSTALLED:
#
#     arcgispro-py36-extras: 0.22-arcgispro_2 esri [arcgispro]
#
# arcgispro-py36   0% |                              | ETA:  --:--:--   0.00  B/s
# arcgispro-py36   1% |                               | ETA:  0:00:57 461.38 kB/s
# arcgispro-py36   2% |                               | ETA:  0:00:40 640.85 kB/s
# arcgispro-py36   3% |                               | ETA:  0:00:30 839.55 kB/s
# arcgispro-py36   4% |#                              | ETA:  0:00:25   1.01 MB/s
# arcgispro-py36   5% |#                              | ETA:  0:00:20   1.21 MB/s
# arcgispro-py36   6% |#                              | ETA:  0:00:18   1.38 MB/s
# arcgispro-py36   7% |##                             | ETA:  0:00:16   1.50 MB/s
# arcgispro-py36   8% |##                             | ETA:  0:00:15   1.62 MB/s
# arcgispro-py36   9% |##                             | ETA:  0:00:13   1.80 MB/s
# arcgispro-py36  10% |###                            | ETA:  0:00:12   1.89 MB/s
# arcgispro-py36  11% |###                            | ETA:  0:00:11   2.00 MB/s
# arcgispro-py36  12% |###                            | ETA:  0:00:10   2.14 MB/s
# arcgispro-py36  13% |####                           | ETA:  0:00:10   2.21 MB/s
# arcgispro-py36  14% |####                           | ETA:  0:00:10   2.25 MB/s
# arcgispro-py36  15% |####                           | ETA:  0:00:09   2.39 MB/s
# arcgispro-py36  16% |#####                          | ETA:  0:00:09   2.46 MB/s
# arcgispro-py36  17% |#####                          | ETA:  0:00:09   2.41 MB/s
# arcgispro-py36  18% |#####                          | ETA:  0:00:08   2.44 MB/s
# arcgispro-py36  19% |######                         | ETA:  0:00:08   2.48 MB/s
# arcgispro-py36  20% |######                         | ETA:  0:00:08   2.54 MB/s
# arcgispro-py36  21% |######                         | ETA:  0:00:08   2.50 MB/s
# arcgispro-py36  22% |#######                        | ETA:  0:00:07   2.62 MB/s
# arcgispro-py36  23% |#######                        | ETA:  0:00:07   2.63 MB/s
# arcgispro-py36  24% |#######                        | ETA:  0:00:07   2.66 MB/s
# arcgispro-py36  26% |########                       | ETA:  0:00:07   2.66 MB/s
# arcgispro-py36  27% |########                       | ETA:  0:00:07   2.66 MB/s
# arcgispro-py36  28% |########                       | ETA:  0:00:07   2.67 MB/s
# arcgispro-py36  29% |#########                      | ETA:  0:00:07   2.69 MB/s
# arcgispro-py36  30% |#########                      | ETA:  0:00:06   2.70 MB/s
# arcgispro-py36  31% |#########                      | ETA:  0:00:06   2.71 MB/s
# arcgispro-py36  32% |##########                     | ETA:  0:00:06   2.72 MB/s
# arcgispro-py36  33% |##########                     | ETA:  0:00:06   2.74 MB/s
# arcgispro-py36  34% |##########                     | ETA:  0:00:06   2.75 MB/s
# arcgispro-py36  35% |##########                     | ETA:  0:00:06   2.76 MB/s
# arcgispro-py36  36% |###########                    | ETA:  0:00:06   2.77 MB/s
# arcgispro-py36  37% |###########                    | ETA:  0:00:06   2.79 MB/s
# arcgispro-py36  38% |###########                    | ETA:  0:00:05   2.80 MB/s
# arcgispro-py36  39% |############                   | ETA:  0:00:05   2.81 MB/s
# arcgispro-py36  40% |############                   | ETA:  0:00:05   2.83 MB/s
# arcgispro-py36  41% |############                   | ETA:  0:00:05   2.84 MB/s
# arcgispro-py36  42% |#############                  | ETA:  0:00:05   2.86 MB/s
# arcgispro-py36  43% |#############                  | ETA:  0:00:05   2.87 MB/s
# arcgispro-py36  44% |#############                  | ETA:  0:00:05   2.88 MB/s
# arcgispro-py36  45% |##############                 | ETA:  0:00:05   2.89 MB/s
# arcgispro-py36  46% |##############                 | ETA:  0:00:04   2.90 MB/s
# arcgispro-py36  47% |##############                 | ETA:  0:00:04   2.91 MB/s
# arcgispro-py36  48% |###############                | ETA:  0:00:04   2.92 MB/s
# arcgispro-py36  49% |###############                | ETA:  0:00:04   2.92 MB/s
# arcgispro-py36  51% |###############                | ETA:  0:00:04   2.93 MB/s
# arcgispro-py36  52% |################               | ETA:  0:00:04   2.93 MB/s
# arcgispro-py36  53% |################               | ETA:  0:00:04   2.54 MB/s
# arcgispro-py36  54% |################               | ETA:  0:00:05   2.24 MB/s
# arcgispro-py36  55% |#################              | ETA:  0:00:05   2.23 MB/s
# arcgispro-py36  56% |#################              | ETA:  0:00:05   2.11 MB/s
# arcgispro-py36  57% |#################              | ETA:  0:00:05   1.97 MB/s
# arcgispro-py36  58% |##################             | ETA:  0:00:06   1.84 MB/s
# arcgispro-py36  59% |##################             | ETA:  0:00:06   1.77 MB/s
# arcgispro-py36  60% |##################             | ETA:  0:00:06   1.71 MB/s
# arcgispro-py36  61% |###################            | ETA:  0:00:06   1.66 MB/s
# arcgispro-py36  62% |###################            | ETA:  0:00:06   1.61 MB/s
# arcgispro-py36  63% |###################            | ETA:  0:00:06   1.56 MB/s
# arcgispro-py36  64% |####################           | ETA:  0:00:06   1.52 MB/s
# arcgispro-py36  65% |####################           | ETA:  0:00:06   1.49 MB/s
# arcgispro-py36  66% |####################           | ETA:  0:00:06   1.46 MB/s
# arcgispro-py36  67% |####################           | ETA:  0:00:06   1.44 MB/s
# arcgispro-py36  68% |#####################          | ETA:  0:00:05   1.41 MB/s
# arcgispro-py36  69% |#####################          | ETA:  0:00:05   1.39 MB/s
# arcgispro-py36  70% |#####################          | ETA:  0:00:05   1.37 MB/s
# arcgispro-py36  71% |######################         | ETA:  0:00:05   1.37 MB/s
# arcgispro-py36  72% |######################         | ETA:  0:00:05   1.35 MB/s
# arcgispro-py36  73% |######################         | ETA:  0:00:05   1.32 MB/s
# arcgispro-py36  74% |#######################        | ETA:  0:00:05   1.27 MB/s
# arcgispro-py36  76% |#######################        | ETA:  0:00:05   1.22 MB/s
# arcgispro-py36  77% |#######################        | ETA:  0:00:05   1.20 MB/s
# arcgispro-py36  78% |########################       | ETA:  0:00:05   1.17 MB/s
# arcgispro-py36  79% |########################       | ETA:  0:00:04   1.16 MB/s
# arcgispro-py36  80% |########################       | ETA:  0:00:04   1.15 MB/s
# arcgispro-py36  81% |#########################      | ETA:  0:00:04   1.14 MB/s
# arcgispro-py36  82% |#########################      | ETA:  0:00:04   1.13 MB/s
# arcgispro-py36  83% |#########################      | ETA:  0:00:03   1.12 MB/s
# arcgispro-py36  84% |##########################     | ETA:  0:00:03   1.11 MB/s
# arcgispro-py36  85% |##########################     | ETA:  0:00:03   1.11 MB/s
# arcgispro-py36  86% |##########################     | ETA:  0:00:03   1.10 MB/s
# arcgispro-py36  87% |###########################    | ETA:  0:00:03   1.10 MB/s
# arcgispro-py36  88% |###########################    | ETA:  0:00:02   1.10 MB/s
# arcgispro-py36  89% |###########################    | ETA:  0:00:02   1.10 MB/s
# arcgispro-py36  90% |############################   | ETA:  0:00:02   1.10 MB/s
# arcgispro-py36  91% |############################   | ETA:  0:00:02   1.10 MB/s
# arcgispro-py36  92% |############################   | ETA:  0:00:01   1.11 MB/s
# arcgispro-py36  93% |#############################  | ETA:  0:00:01   1.11 MB/s
# arcgispro-py36  94% |#############################  | ETA:  0:00:01   1.11 MB/s
# arcgispro-py36  95% |#############################  | ETA:  0:00:01   1.12 MB/s
# arcgispro-py36  96% |############################## | ETA:  0:00:00   1.12 MB/s
# arcgispro-py36  97% |############################## | ETA:  0:00:00   1.13 MB/s
# arcgispro-py36  98% |############################## | ETA:  0:00:00   1.13 MB/s
# arcgispro-py36  99% |############################## | ETA:  0:00:00   1.14 MB/s
# arcgispro-py36 100% |###############################| Time: 0:00:23   1.14 MB/s

# %% [markdown]
# Next steps
# ------------
#
# This provides a brief introduction to using conda. Conda provides a great way of distributing your own work, and creating packages is a great next step if you find its a useful tool for the kind of work you do. The conda documentation has an [in-depth tutorial](https://conda.io/docs/user-guide/tutorials/build-pkgs.html) on creating packages that is a good starting point on how to get into this side of using conda.
